# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv(r"E:\downloads\archive (1)\airlines_flights_data.csv")

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
sn.countplot(x = df['airline'], edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.countplot(x = df['source_city'], edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.countplot(x = df['destination_city'], edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.countplot(x = df['class'] , edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.barplot(x = df['class'] , y = df['price'] , edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.barplot(x = df['airline'] , y = df['price'] , edgecolor = 'Black' , ci = False)
plt.show
# Out:
# C:\Users\Mohamed Ahmed\AppData\Local\Temp\ipykernel_9884\231407983.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sn.barplot(x = df['airline'] , y = df['price'] , edgecolor = 'Black' , ci = False)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.countplot(x = df['departure_time'], edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.countplot(x = df['arrival_time'], edgecolor = 'Black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
